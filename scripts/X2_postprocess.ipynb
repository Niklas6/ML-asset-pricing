# %%
import pandas as pd

# %%
df1=pd.read_csv('../data/results/evaluation/valid_eval_summary.csv')
df2=pd.read_csv('../data/results/evaluation/test1_eval_summary.csv')
df3=pd.read_csv('../data/results/evaluation/test2_eval_summary.csv')
df=pd.concat([df1,df2,df3])


df=df.set_index("year")
#df=df.loc[:,['NN1',	'RF model',	'Ridge model',	'XGBmodel1',	'XGBmodel2'	]]
#display(df)
#display(df.index)
df.plot()
# Out:
# <Axes: xlabel='year'>

# %%
dg1=pd.read_csv('../data/results/evaluation/valid_eval_mean.csv')
dg2=pd.read_csv('../data/results/evaluation/test1_eval_mean.csv')
dg3=pd.read_csv('../data/results/evaluation/test2_eval_mean.csv')





evaluation= pd.DataFrame({
    '1990-1999': dg1.iloc[0,1:],
    '2000-2009': dg2.iloc[0,1:],
    '2010-2019': dg3.iloc[0,1:],
}).T
display(evaluation)
# Out:
#           Extra tree model LGBM model RF model Ridge model XGB model
# 1990-1999            0.031      0.031    0.023       0.029     0.033
# 2000-2009           -0.012     -0.009   -0.021      -0.003    -0.004
# 2010-2019            0.043      0.039    0.038       0.031     0.041
