# %%
import sys
sys.path.append("../")

from src.data_loader import download_price_data, save_raw_data, load_raw_data

# %%
tickers = [
    # Long-history core
    "KO", "PG", "XOM", "CVX", "IBM",
    "MMM", "JNJ", "MRK", "PFE", "BMY",
    "LLY", "ABT", "CL", "GIS", "KMB",
    "MO", "MCD", "DIS", "BA", "CAT",
    "DE", "EMR", "ITW", "SHW", "IP",
    "SO", "DUK", "ED", "AEP", "T",

    # Later but still useful
    "PEP", "WMT", "LOW", "HD", "COST",
    "JPM", "BAC", "WFC", "UNH", "MSFT",
    "AAPL", "INTC", "ORCL", "CSCO", "ADBE",

    # Modern growth/tech
    "AMZN", "GOOGL", "NVDA", "META", "AVGO"
]

# %%
prices, volumes = download_price_data(
    tickers=tickers,
    start_date="1960-01-31",
    end_date="2025-12-31"
)

prices = prices
display(prices.head())
# Out:
#                   KO        PG       XOM       CVX       IBM       MMM  \
# Date
# 1962-01-02  0.044744  0.244460  0.088754  0.307970  1.444739  0.554942
# 1962-01-03  0.043747  0.241788  0.090072  0.307275  1.457368  0.559115
# 1962-01-04  0.044080  0.237781  0.090292  0.304494  1.442845  0.559115
# 1962-01-05  0.043083  0.236111  0.088314  0.296847  1.414429  0.544511
# 1962-01-08  0.042640  0.229766  0.088095  0.295456  1.387908  0.541381
#
#                  JNJ       MRK  PFE  BMY  ...  AAPL  INTC  ORCL  CSCO  ADBE  \
# Date                                      ...
# 1962-01-02  0.060341  0.063742  NaN  NaN  ...   NaN   NaN   NaN   NaN   NaN
# 1962-01-03  0.059403  0.061072  NaN  NaN  ...   NaN   NaN   NaN   NaN   NaN
# 1962-01-04  0.058778  0.060448  NaN  NaN  ...   NaN   NaN   NaN   NaN   NaN
# 1962-01-05  0.057840  0.058401  NaN  NaN  ...   NaN   NaN   NaN   NaN   NaN
# 1962-01-08  0.056902  0.058579  NaN  NaN  ...   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
save_raw_data(prices, volumes, '../data/raw')
